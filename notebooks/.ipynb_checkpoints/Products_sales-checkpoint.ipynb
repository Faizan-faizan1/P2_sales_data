# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 

data = pd.read_csv('~/Desktop/python/Projects/p2/data/raw_data/Products_sales.csv')

# %%
#checking for null and duplicate values
#print(data.isnull().sum())
print(data.duplicated().sum())
# Out:
# 1

# %%
print(data)
# Out:
#     Order ID  Order Date Customer ID     Product     Category  \
# 0     1001.0  01-01-2025        C001      Laptop  Electronics
# 1     1002.0  02-01-2025        C002     Monitor  Electronics
# 2     1003.0  03-01-2025        C003    Keyboard  Accessories
# 3     1004.0  04-01-2025        C004       Mouse  Accessories
# 4     1005.0  05-01-2025        C005  Smartphone  Electronics
# ..       ...         ...         ...         ...          ...
# 56    1057.0  26-02-2025        C057  Desk Chair    Furniture
# 57    1058.0  27-02-2025        C058        Desk    Furniture
# 58    1059.0  28-02-2025        C059  Headphones  Accessories
# 59       NaN         NaN         NaN         NaN          NaN
# 60       NaN         NaN         NaN         NaN          NaN
#
#     Quantity Ordered  Price Each   Sales  Unnamed: 8
# 0                1.0      1000.0  1000.0         NaN
# 1                2.0       200.0   400.0         NaN
# 2                1.0        50.0    50.0         NaN
# 3                2.0        25.0    50.0         NaN
# 4                1.0       800.0   800.0         NaN
# ..               ...         ...     ...         ...
# 56               1.0       150.0   150.0         NaN
# 57               1.0       600.0   600.0         NaN
# 58               3.0       100.0   300.0         NaN
# 59               NaN         NaN     NaN         NaN
# 60               NaN         NaN     NaN         NaN
#
# [61 rows x 9 columns]

# %%
#removing null column 
df = data.drop('Unnamed: 8', axis = 1)
print(df)
# Out:
#     Order ID  Order Date Customer ID     Product     Category  \
# 0     1001.0  01-01-2025        C001      Laptop  Electronics
# 1     1002.0  02-01-2025        C002     Monitor  Electronics
# 2     1003.0  03-01-2025        C003    Keyboard  Accessories
# 3     1004.0  04-01-2025        C004       Mouse  Accessories
# 4     1005.0  05-01-2025        C005  Smartphone  Electronics
# ..       ...         ...         ...         ...          ...
# 56    1057.0  26-02-2025        C057  Desk Chair    Furniture
# 57    1058.0  27-02-2025        C058        Desk    Furniture
# 58    1059.0  28-02-2025        C059  Headphones  Accessories
# 59       NaN         NaN         NaN         NaN          NaN
# 60       NaN         NaN         NaN         NaN          NaN
#
#     Quantity Ordered  Price Each   Sales
# 0                1.0      1000.0  1000.0
# 1                2.0       200.0   400.0
# 2                1.0        50.0    50.0
# 3                2.0        25.0    50.0
# 4                1.0       800.0   800.0
# ..               ...         ...     ...
# 56               1.0       150.0   150.0
# 57               1.0       600.0   600.0
# 58               3.0       100.0   300.0
# 59               NaN         NaN     NaN
# 60               NaN         NaN     NaN
#
# [61 rows x 8 columns]

# %%
#removing null values
df = df.dropna()
print(df)
# Out:
#     Order ID  Order Date Customer ID     Product     Category  \
# 0     1001.0  01-01-2025        C001      Laptop  Electronics
# 1     1002.0  02-01-2025        C002     Monitor  Electronics
# 2     1003.0  03-01-2025        C003    Keyboard  Accessories
# 3     1004.0  04-01-2025        C004       Mouse  Accessories
# 4     1005.0  05-01-2025        C005  Smartphone  Electronics
# 5     1006.0  06-01-2025        C006     Printer  Electronics
# 6     1007.0  07-01-2025        C007  Desk Chair    Furniture
# 7     1008.0  08-01-2025        C008        Desk    Furniture
# 8     1009.0  09-01-2025        C009  Headphones  Accessories
# 9     1010.0  10-01-2025        C010      Webcam  Accessories
# 10    1011.0  11-01-2025        C011      Laptop  Electronics
# 11    1012.0  12-01-2025        C012     Monitor  Electronics
# 12    1013.0  13-01-2025        C013    Keyboard  Accessories
# 13    1014.0  14-01-2025        C014       Mouse  Accessories
# 14    1015.0  15-01-2025        C015  Smartphone  Electronics
# 15    1016.0  16-06-2025        C016     Printer  Electronics
# 16    1017.0  17-06-2025        C017  Desk Chair    Furniture
# 17    1018.0  18-06-2025        C018        Desk    Furniture
# 18    1019.0  19-06-2025        C019  Headphones  Accessories
# 19    1020.0  20-06-2025        C020      Webcam  Accessories
# 20    1021.0  21-01-2025        C021      Laptop  Electronics
# 21    1022.0  22-01-2025        C022     Monitor  Electronics
# 22    1023.0  23-01-2025        C023    Keyboard  Accessories
# 23    1024.0  24-01-2025        C024       Mouse  Accessories
# 24    1025.0  25-01-2025        C025  Smartphone  Electronics
# 25    1026.0  26-01-2025        C026     Printer  Electronics
# 26    1027.0  27-01-2025        C027  Desk Chair    Furniture
# 27    1028.0  28-01-2025        C028        Desk    Furniture
# 28    1029.0  29-01-2025        C029  Headphones  Accessories
# 29    1030.0  30-01-2025        C030      Webcam  Accessories
# 30    1031.0  31-01-2025        C031      Laptop  Electronics
# 31    1032.0  01-02-2025        C032     Monitor  Electronics
# 32    1033.0  02-02-2025        C033    Keyboard  Accessories
# 33    1034.0  03-02-2025        C034       Mouse  Accessories
# 34    1035.0  04-02-2025        C035  Smartphone  Electronics
# 35    1036.0  05-02-2025        C036     Printer  Electronics
# 36    1037.0  06-02-2025        C037  Desk Chair    Furniture
# 37    1038.0  07-02-2025        C038        Desk    Furniture
# 38    1039.0  08-02-2025        C039  Headphones  Accessories
# 39    1040.0  09-02-2025        C040      Webcam  Accessories
# 40    1041.0  10-02-2025        C041      Laptop  Electronics
# 41    1042.0  11-02-2025        C042     Monitor  Electronics
# 42    1043.0  12-02-2025        C043    Keyboard  Accessories
# 43    1044.0  13-02-2025        C044       Mouse  Accessories
# 44    1045.0  14-02-2025        C045  Smartphone  Electronics
# 45    1046.0  15-02-2025        C046     Printer  Electronics
# 46    1047.0  16-02-2025        C047  Desk Chair    Furniture
# 47    1048.0  17-02-2025        C048        Desk    Furniture
# 48    1049.0  18-02-2025        C049  Headphones  Accessories
# 49    1050.0  19-02-2025        C050      Webcam  Accessories
# 50    1051.0  20-02-2025        C051      Laptop  Electronics
# 51    1052.0  21-02-2025        C052     Monitor  Electronics
# 52    1053.0  22-02-2025        C053    Keyboard  Accessories
# 53    1054.0  23-02-2025        C054       Mouse  Accessories
# 54    1055.0  24-02-2025        C055  Smartphone  Electronics
# 55    1056.0  25-02-2025        C056     Printer  Electronics
# 56    1057.0  26-02-2025        C057  Desk Chair    Furniture
# 57    1058.0  27-02-2025        C058        Desk    Furniture
# 58    1059.0  28-02-2025        C059  Headphones  Accessories
#
#     Quantity Ordered  Price Each   Sales
# 0                1.0      1000.0  1000.0
# 1                2.0       200.0   400.0
# 2                1.0        50.0    50.0
# 3                2.0        25.0    50.0
# 4                1.0       800.0   800.0
# 5                1.0       300.0   300.0
# 6                1.0       150.0   150.0
# 7                1.0       250.0   250.0
# 8                1.0        80.0   160.0
# 9                1.0        70.0    70.0
# 10               1.0      1000.0  1000.0
# 11               1.0       200.0   200.0
# 12               1.0        50.0    50.0
# 13               1.0        25.0    25.0
# 14               2.0       800.0  1600.0
# 15               1.0       300.0   300.0
# 16               1.0       150.0   150.0
# 17               1.0       250.0   250.0
# 18               1.0        80.0    80.0
# 19               1.0        70.0    70.0
# 20               1.0       100.0   100.0
# 21               5.0      1000.0  5000.0
# 22               1.0       250.0   250.0
# 23               1.0       360.0   360.0
# 24               1.0       780.0   780.0
# 25               1.0       390.0   390.0
# 26               1.0       100.0   100.0
# 27               1.0      1000.0  1000.0
# 28               1.0       200.0   200.0
# 29               1.0        50.0    50.0
# 30               7.0        25.0   175.0
# 31               1.0       800.0   800.0
# 32               1.0       300.0   300.0
# 33               1.0       150.0   150.0
# 34               1.0       250.0   250.0
# 35               1.0        80.0    80.0
# 36               1.0        70.0    70.0
# 37               1.0      1000.0  1000.0
# 38               1.0       200.0   200.0
# 39               2.0        50.0   100.0
# 40               1.0        25.0    25.0
# 41               1.0       800.0   800.0
# 42               1.0       300.0   300.0
# 43               8.0       150.0  1200.0
# 44               1.0       250.0   250.0
# 45               1.0        80.0    80.0
# 46               1.0        70.0    70.0
# 47               1.0       100.0   100.0
# 48               1.0      1000.0  1000.0
# 49               3.0       250.0   750.0
# 50               1.0       360.0   360.0
# 51               1.0       780.0   780.0
# 52               1.0       390.0   390.0
# 53               1.0       100.0   100.0
# 54               2.0       450.0   900.0
# 55               1.0       780.0   780.0
# 56               1.0       150.0   150.0
# 57               1.0       600.0   600.0
# 58               3.0       100.0   300.0

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
#Checking duplicates in specific columns 
print("Duplicates in Order ID: ",df['Order ID'].duplicated().sum())
print("Duplicates in Order Date: ",df['Order Date'].duplicated().sum())
print("Duplicates in Customer ID: ",df['Customer ID'].duplicated().sum())
# Out:
# Duplicates in Order ID:  0
# Duplicates in Order Date:  0
# Duplicates in Customer ID:  0

# %%
print(df)
# Out:
#     Order ID  Order Date Customer ID     Product     Category  \
# 0     1001.0  01-01-2025        C001      Laptop  Electronics
# 1     1002.0  02-01-2025        C002     Monitor  Electronics
# 2     1003.0  03-01-2025        C003    Keyboard  Accessories
# 3     1004.0  04-01-2025        C004       Mouse  Accessories
# 4     1005.0  05-01-2025        C005  Smartphone  Electronics
# 5     1006.0  06-01-2025        C006     Printer  Electronics
# 6     1007.0  07-01-2025        C007  Desk Chair    Furniture
# 7     1008.0  08-01-2025        C008        Desk    Furniture
# 8     1009.0  09-01-2025        C009  Headphones  Accessories
# 9     1010.0  10-01-2025        C010      Webcam  Accessories
# 10    1011.0  11-01-2025        C011      Laptop  Electronics
# 11    1012.0  12-01-2025        C012     Monitor  Electronics
# 12    1013.0  13-01-2025        C013    Keyboard  Accessories
# 13    1014.0  14-01-2025        C014       Mouse  Accessories
# 14    1015.0  15-01-2025        C015  Smartphone  Electronics
# 15    1016.0  16-06-2025        C016     Printer  Electronics
# 16    1017.0  17-06-2025        C017  Desk Chair    Furniture
# 17    1018.0  18-06-2025        C018        Desk    Furniture
# 18    1019.0  19-06-2025        C019  Headphones  Accessories
# 19    1020.0  20-06-2025        C020      Webcam  Accessories
# 20    1021.0  21-01-2025        C021      Laptop  Electronics
# 21    1022.0  22-01-2025        C022     Monitor  Electronics
# 22    1023.0  23-01-2025        C023    Keyboard  Accessories
# 23    1024.0  24-01-2025        C024       Mouse  Accessories
# 24    1025.0  25-01-2025        C025  Smartphone  Electronics
# 25    1026.0  26-01-2025        C026     Printer  Electronics
# 26    1027.0  27-01-2025        C027  Desk Chair    Furniture
# 27    1028.0  28-01-2025        C028        Desk    Furniture
# 28    1029.0  29-01-2025        C029  Headphones  Accessories
# 29    1030.0  30-01-2025        C030      Webcam  Accessories
# 30    1031.0  31-01-2025        C031      Laptop  Electronics
# 31    1032.0  01-02-2025        C032     Monitor  Electronics
# 32    1033.0  02-02-2025        C033    Keyboard  Accessories
# 33    1034.0  03-02-2025        C034       Mouse  Accessories
# 34    1035.0  04-02-2025        C035  Smartphone  Electronics
# 35    1036.0  05-02-2025        C036     Printer  Electronics
# 36    1037.0  06-02-2025        C037  Desk Chair    Furniture
# 37    1038.0  07-02-2025        C038        Desk    Furniture
# 38    1039.0  08-02-2025        C039  Headphones  Accessories
# 39    1040.0  09-02-2025        C040      Webcam  Accessories
# 40    1041.0  10-02-2025        C041      Laptop  Electronics
# 41    1042.0  11-02-2025        C042     Monitor  Electronics
# 42    1043.0  12-02-2025        C043    Keyboard  Accessories
# 43    1044.0  13-02-2025        C044       Mouse  Accessories
# 44    1045.0  14-02-2025        C045  Smartphone  Electronics
# 45    1046.0  15-02-2025        C046     Printer  Electronics
# 46    1047.0  16-02-2025        C047  Desk Chair    Furniture
# 47    1048.0  17-02-2025        C048        Desk    Furniture
# 48    1049.0  18-02-2025        C049  Headphones  Accessories
# 49    1050.0  19-02-2025        C050      Webcam  Accessories
# 50    1051.0  20-02-2025        C051      Laptop  Electronics
# 51    1052.0  21-02-2025        C052     Monitor  Electronics
# 52    1053.0  22-02-2025        C053    Keyboard  Accessories
# 53    1054.0  23-02-2025        C054       Mouse  Accessories
# 54    1055.0  24-02-2025        C055  Smartphone  Electronics
# 55    1056.0  25-02-2025        C056     Printer  Electronics
# 56    1057.0  26-02-2025        C057  Desk Chair    Furniture
# 57    1058.0  27-02-2025        C058        Desk    Furniture
# 58    1059.0  28-02-2025        C059  Headphones  Accessories
#
#     Quantity Ordered  Price Each   Sales
# 0                1.0      1000.0  1000.0
# 1                2.0       200.0   400.0
# 2                1.0        50.0    50.0
# 3                2.0        25.0    50.0
# 4                1.0       800.0   800.0
# 5                1.0       300.0   300.0
# 6                1.0       150.0   150.0
# 7                1.0       250.0   250.0
# 8                1.0        80.0   160.0
# 9                1.0        70.0    70.0
# 10               1.0      1000.0  1000.0
# 11               1.0       200.0   200.0
# 12               1.0        50.0    50.0
# 13               1.0        25.0    25.0
# 14               2.0       800.0  1600.0
# 15               1.0       300.0   300.0
# 16               1.0       150.0   150.0
# 17               1.0       250.0   250.0
# 18               1.0        80.0    80.0
# 19               1.0        70.0    70.0
# 20               1.0       100.0   100.0
# 21               5.0      1000.0  5000.0
# 22               1.0       250.0   250.0
# 23               1.0       360.0   360.0
# 24               1.0       780.0   780.0
# 25               1.0       390.0   390.0
# 26               1.0       100.0   100.0
# 27               1.0      1000.0  1000.0
# 28               1.0       200.0   200.0
# 29               1.0        50.0    50.0
# 30               7.0        25.0   175.0
# 31               1.0       800.0   800.0
# 32               1.0       300.0   300.0
# 33               1.0       150.0   150.0
# 34               1.0       250.0   250.0
# 35               1.0        80.0    80.0
# 36               1.0        70.0    70.0
# 37               1.0      1000.0  1000.0
# 38               1.0       200.0   200.0
# 39               2.0        50.0   100.0
# 40               1.0        25.0    25.0
# 41               1.0       800.0   800.0
# 42               1.0       300.0   300.0
# 43               8.0       150.0  1200.0
# 44               1.0       250.0   250.0
# 45               1.0        80.0    80.0
# 46               1.0        70.0    70.0
# 47               1.0       100.0   100.0
# 48               1.0      1000.0  1000.0
# 49               3.0       250.0   750.0
# 50               1.0       360.0   360.0
# 51               1.0       780.0   780.0
# 52               1.0       390.0   390.0
# 53               1.0       100.0   100.0
# 54               2.0       450.0   900.0
# 55               1.0       780.0   780.0
# 56               1.0       150.0   150.0
# 57               1.0       600.0   600.0
# 58               3.0       100.0   300.0

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
#How many total orders are there?
Total_orders = df['Order ID'].nunique() #or use .count() if no duplicates
print("Total_orders: ", Total_orders)
# Out:
# Total_orders:  59

# %%
#What is the time range covered by the orders?

df['Order Date'] = pd.to_datetime(df['Order Date'],dayfirst = True,errors = 'coerce')

print(df['Order Date'].dtype)

Time_range = (df['Order Date'].min(),df['Order Date'].max())
print("Time Range: " ,Time_range)
# Out:
# datetime64[ns]
# Time Range:  (Timestamp('2025-01-01 00:00:00'), Timestamp('2025-06-20 00:00:00'))

# %%
#How many unique customers are there?
Total_customers = df['Customer ID'].nunique()
print("Total Customers: ", Total_customers)
# Out:
# Total Customers:  59

# %%
#How many unique products and categories are sold?
Total_products = df['Product'].nunique()
print("Total Unique Products: ", Total_products)

Total_Categories = df['Category'].nunique()
print("Total Unique Categories: ", Total_Categories)
# Out:
# Total Unique Products:  10
# Total Unique Categories:  3

# %%
#What is the total sales amount and total quantity ordered?
Total_sales_amount = df['Sales'].sum()
print("Total sales amount: ",Total_sales_amount)

Total_quantity_ordered = df['Quantity Ordered'].sum()
print("Total Quantity Ordered: ", Total_quantity_ordered)
# Out:
# Total sales amount:  27245.0
# Total Quantity Ordered:  85.0

# %%
# Which product(s) generate the highest sales?
Highest_product_sold = df.groupby('Product')['Sales'].sum().sort_values(ascending = False).reset_index().reset_index()
print("Highest Product sold: \n",Highest_product_sold)
# Out:
# Highest Product sold:
#     index     Product   Sales
# 0      0     Monitor  7980.0
# 1      1  Smartphone  4580.0
# 2      2        Desk  3200.0
# 3      3      Laptop  2660.0
# 4      4  Headphones  1940.0
# 5      5     Printer  1930.0
# 6      6       Mouse  1885.0
# 7      7    Keyboard  1340.0
# 8      8      Webcam  1040.0
# 9      9  Desk Chair   690.0

# %%
#Which category has the highest total sales?
Highest_category_sold = df.groupby('Category')['Sales'].sum().sort_values(ascending = False)
print("Highest Category solf: \n",Highest_category_sold)
# Out:
# Highest Category solf:
#  Category
# Electronics    17150.0
# Accessories     6205.0
# Furniture       3890.0
# Name: Sales, dtype: float64

# %%
#What is the average sales per order?
average_sales = df.groupby('Order ID')['Sales'].sum().mean()
print("Average Sales per order: \n",average_sales)
# Out:
# Average Sales per order:
#  461.77966101694915

# %%
#Distribution of quantity ordered?
quantity_distribution = df['Quantity Ordered'].value_counts().sort_index()
print(quantity_distribution)
# Out:
# Quantity Ordered
# 1.0    49
# 2.0     5
# 3.0     2
# 5.0     1
# 7.0     1
# 8.0     1
# Name: count, dtype: int64

# %%
#Sales trends over time (daily)

daily_sales = df.groupby('Order Date')['Sales'].sum().reset_index()


import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.lineplot(data=daily_sales, x='Order Date', y='Sales',palette = 'rocket')

plt.title('📈 Daily Sales Over Time')
plt.xlabel('Order Date')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HOME\AppData\Local\Temp\ipykernel_9928\3787882854.py:10: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=daily_sales, x='Order Date', y='Sales',palette = 'rocket')
# C:\Users\HOME\AppData\Local\Temp\ipykernel_9928\3787882854.py:16: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\HOME\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#Which products generate the highest revenue?
#Highest_product_sold = df.groupby('Product')['Sales'].sum().sort_values(ascending = False)

sns.barplot(data = Highest_product_sold, x = 'Product', y = 'Sales', hue = 'Product',palette = 'rocket')
plt.title('Sales by Products')
plt.tight_layout()
plt.xticks(rotation = 45)
plt.show()

# %%
 #Sales by Category (Pie Chart)

plt.pie(Highest_category_sold,labels = Highest_category_sold.index, autopct = '%1.1f%%')
plt.title('Sales by Category')
plt.show()

# %%
#Sales by Day of Week (Bar Plot)

df['day of week'] = df['Order Date'].dt.day_name()
weekday_sales = df.groupby('day of week')['Sales'].sum().reindex(['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])

sns.barplot(x =weekday_sales.index , y = weekday_sales.values,palette = 'rocket')
plt.title('Sales by day of week')
plt.show()
# Out:
# C:\Users\HOME\AppData\Local\Temp\ipykernel_9928\1302539856.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x =weekday_sales.index , y = weekday_sales.values,palette = 'rocket')

# %%
#Price vs Quantity Ordered (Scatter Plot)
#Is there any pattern between product price and quantity ordered?

sns.scatterplot(data = df, x = 'Price Each', y = 'Quantity Ordered', hue = 'Category', palette = 'rocket')
plt.title('Price vs Quantity Ordered')
plt.xlabel('Price')
plt.ylabel('Quantity Ordered')
plt.tight_layout()
plt.show()
